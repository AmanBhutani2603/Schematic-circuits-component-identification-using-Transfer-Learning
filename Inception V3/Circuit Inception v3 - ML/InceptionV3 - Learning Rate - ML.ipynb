# %% [markdown]
# ### Mounting drive on Colab

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount = True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# ###Libraries

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.15.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.9 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.15.0

# %%
import os
import cv2
import os
import h5py
import numpy as np
import pickle
from tqdm import tqdm
from PIL import Image
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow_addons.metrics import HammingLoss
from tensorflow_addons.metrics import F1Score
os.chdir('/gdrive/My Drive/')
from numpy import savez_compressed
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance
import tensorflow_datasets as tfds
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras import layers, models
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model

# %% [markdown]
# ## Effect of changing learning rate
#
# For studying the effects of learning rate it is varied in the range of 10^-5 to 10^2

# %% [markdown]
# ### For ImageNet as a source

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from timeit import default_timer as timer

class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

pre_trained_model = InceptionV3(input_shape = (96, 96, 3), 
                                include_top = False, 
                                weights = 'None')
#for layer in pre_trained_model.layers:
#  layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
def compile_model(learning_rate):
  from tensorflow.keras.optimizers import RMSprop

  # Flatten the output layer to 1 dimension
  x = layers.Flatten()(pre_trained_model.output)

  # Add a fully connected layer with "num_neurons" hidden units and ReLU activation
  x = layers.Dense(2000, activation='relu')(x)

  x = layers.Dense(1000, activation='relu')(x)

  x = layers.Dense(500, activation='relu')(x)                  
  
  # Add a final sigmoid layer for classification
  x = layers.Dense  (15, activation='softmax')(x)           

  model = Model( pre_trained_model.input, x) 

  model.compile(optimizer = RMSprop(lr=learning_rate), 
              loss = 'categorical_crossentropy', 
              metrics = ['acc', tf.keras.metrics.AUC(), tf.keras.metrics.Recall(), tf.keras.metrics.Precision(), HammingLoss(threshold=0.5, mode='multiclass'), F1Score(num_classes= 15, threshold=0.5)])
  return model

# %%
data = np.load('Xtrain.npy', allow_pickle=True)
labels = np.load('ytrain.npy', allow_pickle=True)

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size = 0.2, random_state = 42, stratify = labels)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %%
y_train = to_categorical(y_train, 15)
y_val = to_categorical(y_val, 15)
y_test = to_categorical(y_test, 15)

# %%
for i in [10**-5, 10**-4, 10**-3, 10**-2, 10**-1]:
  print("*********** Fitting model for learning rate of", i ,"***************")
  model = compile_model(i)
  model.fit(X_train, y_train, batch_size = 120, epochs=10, validation_data=(X_val, y_val), callbacks = [cb])
  test_acc = model.evaluate(X_test, y_test)
  print("***********test accuracy is", test_acc,"***************")
  print("***********train time is", sum(cb.logs),"***************")
  print("f1 score is", sum(test_acc[6])/15)
# Out:
# *********** Fitting model for learning rate of 1e-05 ***************
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# Epoch 1/10
# 200/200 [==============================] - 52s 134ms/step - loss: 8.3540 - acc: 0.1317 - auc: 0.5796 - recall: 0.1054 - precision: 0.1391 - hamming_loss: 0.8946 - val_loss: 5.7563 - val_acc: 0.1573 - val_auc: 0.6137 - val_recall: 0.1260 - val_precision: 0.1714 - val_hamming_loss: 0.8740
# Epoch 2/10
# 200/200 [==============================] - 25s 125ms/step - loss: 4.7902 - acc: 0.2029 - auc: 0.6600 - recall: 0.1563 - precision: 0.2302 - hamming_loss: 0.8437 - val_loss: 4.7591 - val_acc: 0.1953 - val_auc: 0.6545 - val_recall: 0.1453 - val_precision: 0.2189 - val_hamming_loss: 0.8547
# Epoch 3/10
# 200/200 [==============================] - 25s 126ms/step - loss: 4.0848 - acc: 0.2464 - auc: 0.6978 - recall: 0.1883 - precision: 0.2848 - hamming_loss: 0.8117 - val_loss: 4.6959 - val_acc: 0.2110 - val_auc: 0.6697 - val_recall: 0.1727 - val_precision: 0.2287 - val_hamming_loss: 0.8273
# Epoch 4/10
# 200/200 [==============================] - 25s 125ms/step - loss: 3.6129 - acc: 0.2784 - auc: 0.7277 - recall: 0.2152 - precision: 0.3342 - hamming_loss: 0.7848 - val_loss: 3.9104 - val_acc: 0.2753 - val_auc: 0.7115 - val_recall: 0.2067 - val_precision: 0.3085 - val_hamming_loss: 0.7933
# Epoch 5/10
# 200/200 [==============================] - 25s 124ms/step - loss: 3.2929 - acc: 0.3092 - auc: 0.7510 - recall: 0.2407 - precision: 0.3776 - hamming_loss: 0.7593 - val_loss: 3.9166 - val_acc: 0.2850 - val_auc: 0.7133 - val_recall: 0.2240 - val_precision: 0.3276 - val_hamming_loss: 0.7760
# Epoch 6/10
# 200/200 [==============================] - 25s 124ms/step - loss: 3.0364 - acc: 0.3322 - auc: 0.7709 - recall: 0.2582 - precision: 0.4072 - hamming_loss: 0.7418 - val_loss: 3.6407 - val_acc: 0.2890 - val_auc: 0.7252 - val_recall: 0.2220 - val_precision: 0.3330 - val_hamming_loss: 0.7780
# Epoch 7/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.8388 - acc: 0.3553 - auc: 0.7873 - recall: 0.2743 - precision: 0.4357 - hamming_loss: 0.7257 - val_loss: 2.8468 - val_acc: 0.3450 - val_auc: 0.7861 - val_recall: 0.2460 - val_precision: 0.4261 - val_hamming_loss: 0.7540
# Epoch 8/10
# 200/200 [==============================] - 25s 125ms/step - loss: 2.6709 - acc: 0.3774 - auc: 0.8008 - recall: 0.2909 - precision: 0.4622 - hamming_loss: 0.7091 - val_loss: 3.1221 - val_acc: 0.3450 - val_auc: 0.7683 - val_recall: 0.2723 - val_precision: 0.4201 - val_hamming_loss: 0.7277
# Epoch 9/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.5353 - acc: 0.3964 - auc: 0.8140 - recall: 0.3098 - precision: 0.4846 - hamming_loss: 0.6902 - val_loss: 3.2093 - val_acc: 0.3460 - val_auc: 0.7691 - val_recall: 0.2677 - val_precision: 0.4184 - val_hamming_loss: 0.7323
# Epoch 10/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.4050 - acc: 0.4160 - auc: 0.8250 - recall: 0.3257 - precision: 0.5101 - hamming_loss: 0.6743 - val_loss: 2.6004 - val_acc: 0.3850 - val_auc: 0.8086 - val_recall: 0.2840 - val_precision: 0.4792 - val_hamming_loss: 0.7160
# 94/94 [==============================] - 9s 68ms/step - loss: 2.6082 - acc: 0.3867 - auc: 0.8085 - recall: 0.2890 - precision: 0.4738 - hamming_loss: 0.7110
# ***********test accuracy is [2.608193874359131, 0.3866666555404663, 0.8085368275642395, 0.289000004529953, 0.47377049922943115, 0.7110000252723694] ***************
# ***********train time is 275.98914858800003 ***************
# *********** Fitting model for learning rate of 0.0001 ***************
# Epoch 1/10
# 200/200 [==============================] - 33s 135ms/step - loss: 11.3846 - acc: 0.1235 - auc_1: 0.5609 - recall_1: 0.0853 - precision_1: 0.1290 - hamming_loss: 0.9147 - val_loss: 3.9204 - val_acc: 0.1570 - val_auc_1: 0.6089 - val_recall_1: 0.0750 - val_precision_1: 0.2324 - val_hamming_loss: 0.9250
# Epoch 2/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.9716 - acc: 0.1968 - auc_1: 0.6710 - recall_1: 0.0812 - precision_1: 0.3326 - hamming_loss: 0.9187 - val_loss: 2.4806 - val_acc: 0.2293 - val_auc_1: 0.7218 - val_recall_1: 0.0903 - val_precision_1: 0.5094 - val_hamming_loss: 0.9097
# Epoch 3/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.4103 - acc: 0.2670 - auc_1: 0.7483 - recall_1: 0.1062 - precision_1: 0.5222 - hamming_loss: 0.8938 - val_loss: 2.3320 - val_acc: 0.2820 - val_auc_1: 0.7644 - val_recall_1: 0.1083 - val_precision_1: 0.5102 - val_hamming_loss: 0.8917
# Epoch 4/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.1731 - acc: 0.3233 - auc_1: 0.7960 - recall_1: 0.1453 - precision_1: 0.6048 - hamming_loss: 0.8547 - val_loss: 2.1816 - val_acc: 0.3393 - val_auc_1: 0.7959 - val_recall_1: 0.1483 - val_precision_1: 0.6303 - val_hamming_loss: 0.8517
# Epoch 5/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.0023 - acc: 0.3745 - auc_1: 0.8296 - recall_1: 0.1883 - precision_1: 0.6604 - hamming_loss: 0.8117 - val_loss: 2.0460 - val_acc: 0.3630 - val_auc_1: 0.8236 - val_recall_1: 0.1823 - val_precision_1: 0.6428 - val_hamming_loss: 0.8177
# Epoch 6/10
# 200/200 [==============================] - 25s 124ms/step - loss: 1.8732 - acc: 0.4120 - auc_1: 0.8534 - recall_1: 0.2268 - precision_1: 0.6885 - hamming_loss: 0.7732 - val_loss: 1.8946 - val_acc: 0.4117 - val_auc_1: 0.8527 - val_recall_1: 0.2337 - val_precision_1: 0.6708 - val_hamming_loss: 0.7663
# Epoch 7/10
# 200/200 [==============================] - 25s 124ms/step - loss: 1.7388 - acc: 0.4476 - auc_1: 0.8753 - recall_1: 0.2689 - precision_1: 0.7131 - hamming_loss: 0.7311 - val_loss: 1.8239 - val_acc: 0.4343 - val_auc_1: 0.8628 - val_recall_1: 0.2367 - val_precision_1: 0.7037 - val_hamming_loss: 0.7633
# Epoch 8/10
# 200/200 [==============================] - 25s 125ms/step - loss: 1.6515 - acc: 0.4742 - auc_1: 0.8882 - recall_1: 0.3025 - precision_1: 0.7287 - hamming_loss: 0.6975 - val_loss: 1.7594 - val_acc: 0.4433 - val_auc_1: 0.8753 - val_recall_1: 0.2617 - val_precision_1: 0.7021 - val_hamming_loss: 0.7383
# Epoch 9/10
# 200/200 [==============================] - 25s 124ms/step - loss: 1.5419 - acc: 0.5098 - auc_1: 0.9033 - recall_1: 0.3377 - precision_1: 0.7520 - hamming_loss: 0.6623 - val_loss: 1.8071 - val_acc: 0.4483 - val_auc_1: 0.8701 - val_recall_1: 0.3003 - val_precision_1: 0.6920 - val_hamming_loss: 0.6997
# Epoch 10/10
# 200/200 [==============================] - 25s 124ms/step - loss: 1.4600 - acc: 0.5338 - auc_1: 0.9136 - recall_1: 0.3747 - precision_1: 0.7636 - hamming_loss: 0.6253 - val_loss: 1.9552 - val_acc: 0.4030 - val_auc_1: 0.8569 - val_recall_1: 0.2653 - val_precision_1: 0.5739 - val_hamming_loss: 0.7347
# 94/94 [==============================] - 8s 61ms/step - loss: 1.9985 - acc: 0.3907 - auc_1: 0.8521 - recall_1: 0.2583 - precision_1: 0.5686 - hamming_loss: 0.7417
# ***********test accuracy is [1.9985493421554565, 0.390666663646698, 0.8521338105201721, 0.25833332538604736, 0.5685986876487732, 0.7416666746139526] ***************
# ***********train time is 532.6589388560001 ***************
# *********** Fitting model for learning rate of 0.001 ***************
# Epoch 1/10
# 200/200 [==============================] - 34s 139ms/step - loss: 22.9897 - acc: 0.0875 - auc_2: 0.5253 - recall_2: 0.0236 - precision_2: 0.1014 - hamming_loss: 0.9764 - val_loss: 2.6797 - val_acc: 0.1003 - val_auc_2: 0.5507 - val_recall_2: 0.0100 - val_precision_2: 0.4615 - val_hamming_loss: 0.9900
# Epoch 2/10
# 200/200 [==============================] - 25s 125ms/step - loss: 2.7351 - acc: 0.0908 - auc_2: 0.5377 - recall_2: 0.0124 - precision_2: 0.4481 - hamming_loss: 0.9876 - val_loss: 2.6742 - val_acc: 0.0860 - val_auc_2: 0.5266 - val_recall_2: 0.0090 - val_precision_2: 0.9643 - val_hamming_loss: 0.9910
# Epoch 3/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.6692 - acc: 0.1027 - auc_2: 0.5719 - recall_2: 0.0190 - precision_2: 0.5966 - hamming_loss: 0.9810 - val_loss: 2.5976 - val_acc: 0.1037 - val_auc_2: 0.6101 - val_recall_2: 0.0193 - val_precision_2: 0.7945 - val_hamming_loss: 0.9807
# Epoch 4/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.6024 - acc: 0.1251 - auc_2: 0.6272 - recall_2: 0.0236 - precision_2: 0.6220 - hamming_loss: 0.9764 - val_loss: 2.6272 - val_acc: 0.1010 - val_auc_2: 0.5874 - val_recall_2: 0.0150 - val_precision_2: 0.9184 - val_hamming_loss: 0.9850
# Epoch 5/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.5338 - acc: 0.1462 - auc_2: 0.6667 - recall_2: 0.0293 - precision_2: 0.6362 - hamming_loss: 0.9707 - val_loss: 2.4736 - val_acc: 0.1540 - val_auc_2: 0.6940 - val_recall_2: 0.0193 - val_precision_2: 0.7073 - val_hamming_loss: 0.9807
# Epoch 6/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.4659 - acc: 0.1745 - auc_2: 0.7001 - recall_2: 0.0349 - precision_2: 0.6656 - hamming_loss: 0.9651 - val_loss: 2.4490 - val_acc: 0.1767 - val_auc_2: 0.7086 - val_recall_2: 0.0320 - val_precision_2: 0.7007 - val_hamming_loss: 0.9680
# Epoch 7/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.4270 - acc: 0.1847 - auc_2: 0.7173 - recall_2: 0.0416 - precision_2: 0.6739 - hamming_loss: 0.9584 - val_loss: 2.3664 - val_acc: 0.2003 - val_auc_2: 0.7375 - val_recall_2: 0.0390 - val_precision_2: 0.7548 - val_hamming_loss: 0.9610
# Epoch 8/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.3861 - acc: 0.2003 - auc_2: 0.7329 - recall_2: 0.0499 - precision_2: 0.6848 - hamming_loss: 0.9501 - val_loss: 2.3267 - val_acc: 0.2133 - val_auc_2: 0.7524 - val_recall_2: 0.0623 - val_precision_2: 0.6404 - val_hamming_loss: 0.9377
# Epoch 9/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.3335 - acc: 0.2154 - auc_2: 0.7481 - recall_2: 0.0562 - precision_2: 0.7050 - hamming_loss: 0.9438 - val_loss: 2.2968 - val_acc: 0.2357 - val_auc_2: 0.7592 - val_recall_2: 0.0517 - val_precision_2: 0.7949 - val_hamming_loss: 0.9483
# Epoch 10/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.3109 - acc: 0.2241 - auc_2: 0.7564 - recall_2: 0.0631 - precision_2: 0.7035 - hamming_loss: 0.9369 - val_loss: 2.3194 - val_acc: 0.2213 - val_auc_2: 0.7543 - val_recall_2: 0.0783 - val_precision_2: 0.6369 - val_hamming_loss: 0.9217
# 94/94 [==============================] - 8s 61ms/step - loss: 2.3184 - acc: 0.2197 - auc_2: 0.7560 - recall_2: 0.0863 - precision_2: 0.6080 - hamming_loss: 0.9137
# ***********test accuracy is [2.318378210067749, 0.21966665983200073, 0.7559984922409058, 0.08633333444595337, 0.6079812049865723, 0.9136666655540466] ***************
# ***********train time is 789.559760419 ***************
# *********** Fitting model for learning rate of 0.01 ***************
# Epoch 1/10
# 200/200 [==============================] - 33s 134ms/step - loss: 2888.0991 - acc: 0.0672 - auc_3: 0.5007 - recall_3: 0.0084 - precision_3: 0.0778 - hamming_loss: 0.9916 - val_loss: 2.7094 - val_acc: 0.0667 - val_auc_3: 0.4998 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 2/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7092 - acc: 0.0645 - auc_3: 0.4966 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7084 - val_acc: 0.0660 - val_auc_3: 0.4994 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 3/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7091 - acc: 0.0631 - auc_3: 0.4972 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7087 - val_acc: 0.0667 - val_auc_3: 0.5000 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 4/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7092 - acc: 0.0657 - auc_3: 0.4966 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7087 - val_acc: 0.0667 - val_auc_3: 0.4997 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 5/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7093 - acc: 0.0653 - auc_3: 0.4953 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7083 - val_acc: 0.0667 - val_auc_3: 0.5007 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 6/10
# 200/200 [==============================] - 25s 125ms/step - loss: 2.7092 - acc: 0.0650 - auc_3: 0.4963 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7084 - val_acc: 0.0667 - val_auc_3: 0.5004 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 7/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7089 - acc: 0.0663 - auc_3: 0.4985 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7085 - val_acc: 0.0673 - val_auc_3: 0.4999 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 8/10
# 200/200 [==============================] - 25s 125ms/step - loss: 2.7092 - acc: 0.0616 - auc_3: 0.4949 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7086 - val_acc: 0.0673 - val_auc_3: 0.5006 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 9/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7091 - acc: 0.0668 - auc_3: 0.4986 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7089 - val_acc: 0.0667 - val_auc_3: 0.5006 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 10/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7092 - acc: 0.0671 - auc_3: 0.4982 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7085 - val_acc: 0.0673 - val_auc_3: 0.5004 - val_recall_3: 0.0000e+00 - val_precision_3: 0.0000e+00 - val_hamming_loss: 1.0000
# 94/94 [==============================] - 8s 60ms/step - loss: 2.7085 - acc: 0.0673 - auc_3: 0.5004 - recall_3: 0.0000e+00 - precision_3: 0.0000e+00 - hamming_loss: 1.0000
# ***********test accuracy is [2.708523750305176, 0.06733333319425583, 0.5003571510314941, 0.0, 0.0, 1.0] ***************
# ***********train time is 1046.0428200709998 ***************
# *********** Fitting model for learning rate of 0.1 ***************
# Epoch 1/10
# 200/200 [==============================] - 33s 134ms/step - loss: 24148426.0000 - acc: 0.0668 - auc_4: 0.4979 - recall_4: 0.0041 - precision_4: 0.0645 - hamming_loss: 0.9959 - val_loss: 2.7154 - val_acc: 0.0667 - val_auc_4: 0.4993 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 2/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7176 - acc: 0.0648 - auc_4: 0.4982 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7136 - val_acc: 0.0660 - val_auc_4: 0.4995 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 3/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7175 - acc: 0.0648 - auc_4: 0.4986 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7161 - val_acc: 0.0667 - val_auc_4: 0.4997 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 4/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7169 - acc: 0.0669 - auc_4: 0.4995 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7176 - val_acc: 0.0667 - val_auc_4: 0.5000 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 5/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7179 - acc: 0.0659 - auc_4: 0.4977 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7129 - val_acc: 0.0667 - val_auc_4: 0.4999 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 6/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7174 - acc: 0.0634 - auc_4: 0.4979 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7145 - val_acc: 0.0667 - val_auc_4: 0.4999 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 7/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7179 - acc: 0.0655 - auc_4: 0.4958 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7175 - val_acc: 0.0667 - val_auc_4: 0.4999 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 8/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7164 - acc: 0.0659 - auc_4: 0.5018 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7180 - val_acc: 0.0667 - val_auc_4: 0.5000 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 9/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7170 - acc: 0.0661 - auc_4: 0.4983 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7145 - val_acc: 0.0673 - val_auc_4: 0.5002 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# Epoch 10/10
# 200/200 [==============================] - 25s 124ms/step - loss: 2.7171 - acc: 0.0668 - auc_4: 0.4994 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000 - val_loss: 2.7157 - val_acc: 0.0667 - val_auc_4: 0.5007 - val_recall_4: 0.0000e+00 - val_precision_4: 0.0000e+00 - val_hamming_loss: 1.0000
# 94/94 [==============================] - 8s 60ms/step - loss: 2.7157 - acc: 0.0667 - auc_4: 0.5007 - recall_4: 0.0000e+00 - precision_4: 0.0000e+00 - hamming_loss: 1.0000
# ***********test accuracy is [2.7156786918640137, 0.06666667014360428, 0.5006666779518127, 0.0, 0.0, 1.0] ***************
# ***********train time is 1302.2271685489995 ***************
