# %% [markdown]
# ### Mounting drive on Colab

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount = True)
# Out:
# Mounted at /gdrive

# %% [markdown]
# ###Libraries

# %%
# !pip install tensorflow_addons
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.0 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
import os
import cv2
import os
import h5py
import numpy as np
import pickle
from tqdm import tqdm
from PIL import Image
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow_addons.metrics import HammingLoss
from tensorflow_addons.metrics import F1Score
os.chdir('/gdrive/My Drive/')
from numpy import savez_compressed
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance
import tensorflow_datasets as tfds
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras import layers, models
import tensorflow.keras as keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras import Model

# %% [markdown]
# ## Changing Momentum

# %% [markdown]
# ### For ImageNet as a source

# %%
from tensorflow.keras.applications.resnet50 import ResNet50

from timeit import default_timer as timer

class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

cb = TimingCallback()

pre_trained_model = ResNet50(input_shape = (96, 96, 3), 
                                include_top = False, 
                                weights = None)
#for layer in pre_trained_model.layers:
#  layer.trainable = False

# %%
def compile_model(rate):
  from tensorflow.keras.optimizers import SGD

  # Flatten the output layer to 1 dimension
  x = layers.Flatten()(pre_trained_model.output)
  # Add a fully connected layer with 2000 hidden units and ReLU activation
  x = layers.Dense(2000, activation='relu')(x)
  # Add a fully connected layer with 2000 hidden units and ReLU activation
  x = layers.Dense(1000, activation='relu')(x)
  # Add a fully connected layer with 2000 hidden units and ReLU activation
  x = layers.Dense(500, activation='relu')(x)                  
  # Add a final sigmoid layer for classification
  x = layers.Dense  (15, activation='softmax')(x)           

  model = Model( pre_trained_model.input, x) 

  model.compile(optimizer = SGD(lr=0.0001, momentum = rate), 
              loss = 'categorical_crossentropy', 
              metrics = ['acc', tf.keras.metrics.AUC(), tf.keras.metrics.Recall(), tf.keras.metrics.Precision(), HammingLoss(threshold=0.5, mode='multiclass'), F1Score(num_classes= 15, threshold=0.5)])
  return model

# %%
data = np.load('Xtrain.npy', allow_pickle=True)
labels = np.load('ytrain.npy', allow_pickle=True)

X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size = 0.2, random_state = 42, stratify = labels)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size = 0.5, random_state = 42, stratify = y_test)

# %%
y_train = to_categorical(y_train, 15)
y_val = to_categorical(y_val, 15)
y_test = to_categorical(y_test, 15)

# %%
rate = 0
for i in range(0, 10):
  print("******************* Training model for momentum of", rate, "************************")
  rate = rate + 0.1
  imagenet_resnet50 = compile_model(rate)
  history = imagenet_resnet50.fit(X_train, y_train, batch_size = 120, epochs=10, validation_data=(X_val, y_val), callbacks = [cb])
  print("******************* Model evaluation for a momentum of", rate, "*************************")
  eval = imagenet_resnet50.evaluate(X_test, y_test)
  print("******************* Train time is", sum(cb.logs), "***********")
  print("f1 score is", sum(eval[6])/15)
# Out:
# ******************* Training model for momentum of 0 ************************
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/10
# 200/200 [==============================] - 164s 787ms/step - loss: 2.9147 - acc: 0.0644 - auc_1: 0.5052 - recall_1: 0.0010 - precision_1: 0.0619 - hamming_loss: 0.9990 - f1_score: 0.0020 - val_loss: 2.7311 - val_acc: 0.0723 - val_auc_1: 0.5013 - val_recall_1: 0.0000e+00 - val_precision_1: 0.0000e+00 - val_hamming_loss: 1.0000 - val_f1_score: 0.0000e+00
# Epoch 2/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.8504 - acc: 0.0710 - auc_1: 0.5090 - recall_1: 0.0014 - precision_1: 0.1191 - hamming_loss: 0.9986 - f1_score: 0.0026 - val_loss: 2.7809 - val_acc: 0.0737 - val_auc_1: 0.5116 - val_recall_1: 6.6667e-04 - val_precision_1: 0.6667 - val_hamming_loss: 0.9993 - val_f1_score: 0.0013
# Epoch 3/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.8314 - acc: 0.0712 - auc_1: 0.5116 - recall_1: 0.0016 - precision_1: 0.1667 - hamming_loss: 0.9984 - f1_score: 0.0031 - val_loss: 2.8665 - val_acc: 0.0697 - val_auc_1: 0.5076 - val_recall_1: 0.0010 - val_precision_1: 0.0811 - val_hamming_loss: 0.9990 - val_f1_score: 0.0019
# Epoch 4/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.8197 - acc: 0.0744 - auc_1: 0.5119 - recall_1: 0.0020 - precision_1: 0.1975 - hamming_loss: 0.9980 - f1_score: 0.0039 - val_loss: 2.8300 - val_acc: 0.0767 - val_auc_1: 0.5223 - val_recall_1: 0.0020 - val_precision_1: 0.1277 - val_hamming_loss: 0.9980 - val_f1_score: 0.0038
# Epoch 5/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.8048 - acc: 0.0725 - auc_1: 0.5173 - recall_1: 0.0016 - precision_1: 0.1980 - hamming_loss: 0.9984 - f1_score: 0.0032 - val_loss: 2.8208 - val_acc: 0.0760 - val_auc_1: 0.5128 - val_recall_1: 0.0017 - val_precision_1: 0.1389 - val_hamming_loss: 0.9983 - val_f1_score: 0.0032
# Epoch 6/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7979 - acc: 0.0734 - auc_1: 0.5144 - recall_1: 0.0016 - precision_1: 0.2143 - hamming_loss: 0.9984 - f1_score: 0.0031 - val_loss: 2.8480 - val_acc: 0.0653 - val_auc_1: 0.5140 - val_recall_1: 0.0020 - val_precision_1: 0.1250 - val_hamming_loss: 0.9980 - val_f1_score: 0.0038
# Epoch 7/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7828 - acc: 0.0784 - auc_1: 0.5192 - recall_1: 0.0017 - precision_1: 0.2273 - hamming_loss: 0.9983 - f1_score: 0.0032 - val_loss: 2.7975 - val_acc: 0.0720 - val_auc_1: 0.5258 - val_recall_1: 0.0020 - val_precision_1: 0.1818 - val_hamming_loss: 0.9980 - val_f1_score: 0.0038
# Epoch 8/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7762 - acc: 0.0737 - auc_1: 0.5207 - recall_1: 0.0017 - precision_1: 0.2439 - hamming_loss: 0.9983 - f1_score: 0.0033 - val_loss: 2.8037 - val_acc: 0.0767 - val_auc_1: 0.5160 - val_recall_1: 0.0017 - val_precision_1: 0.1724 - val_hamming_loss: 0.9983 - val_f1_score: 0.0032
# Epoch 9/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7707 - acc: 0.0743 - auc_1: 0.5193 - recall_1: 0.0017 - precision_1: 0.2595 - hamming_loss: 0.9983 - f1_score: 0.0033 - val_loss: 2.7612 - val_acc: 0.0797 - val_auc_1: 0.5248 - val_recall_1: 0.0020 - val_precision_1: 0.2609 - val_hamming_loss: 0.9980 - val_f1_score: 0.0038
# Epoch 10/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7654 - acc: 0.0754 - auc_1: 0.5193 - recall_1: 0.0017 - precision_1: 0.2985 - hamming_loss: 0.9983 - f1_score: 0.0032 - val_loss: 2.7709 - val_acc: 0.0767 - val_auc_1: 0.5167 - val_recall_1: 0.0030 - val_precision_1: 0.3214 - val_hamming_loss: 0.9970 - val_f1_score: 0.0057
# ******************* Model evaluation for a momentum of 0.1 *************************
# 94/94 [==============================] - 10s 85ms/step - loss: 2.7606 - acc: 0.0823 - auc_1: 0.5317 - recall_1: 0.0023 - precision_1: 0.2500 - hamming_loss: 0.9977 - f1_score: 0.0045
# ******************* Train time is 1566.8787233299995 ***********
# f1 score is 0.004463281979163488
# ******************* Training model for momentum of 0.1 ************************
# Epoch 1/10
# 200/200 [==============================] - 165s 790ms/step - loss: 2.9176 - acc: 0.0672 - auc_2: 0.5087 - recall_2: 0.0019 - precision_2: 0.1064 - hamming_loss: 0.9981 - f1_score: 0.0036 - val_loss: 2.8620 - val_acc: 0.0697 - val_auc_2: 0.5044 - val_recall_2: 0.0017 - val_precision_2: 0.1250 - val_hamming_loss: 0.9983 - val_f1_score: 0.0031
# Epoch 2/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.8279 - acc: 0.0719 - auc_2: 0.5151 - recall_2: 0.0021 - precision_2: 0.1639 - hamming_loss: 0.9979 - f1_score: 0.0040 - val_loss: 2.8745 - val_acc: 0.0660 - val_auc_2: 0.5057 - val_recall_2: 0.0030 - val_precision_2: 0.1216 - val_hamming_loss: 0.9970 - val_f1_score: 0.0055
# Epoch 3/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.8120 - acc: 0.0746 - auc_2: 0.5155 - recall_2: 0.0028 - precision_2: 0.2100 - hamming_loss: 0.9972 - f1_score: 0.0054 - val_loss: 2.8238 - val_acc: 0.0650 - val_auc_2: 0.5117 - val_recall_2: 0.0047 - val_precision_2: 0.2692 - val_hamming_loss: 0.9953 - val_f1_score: 0.0088
# Epoch 4/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7909 - acc: 0.0773 - auc_2: 0.5224 - recall_2: 0.0028 - precision_2: 0.2403 - hamming_loss: 0.9972 - f1_score: 0.0055 - val_loss: 2.8278 - val_acc: 0.0703 - val_auc_2: 0.5139 - val_recall_2: 0.0033 - val_precision_2: 0.2083 - val_hamming_loss: 0.9967 - val_f1_score: 0.0064
# Epoch 5/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7884 - acc: 0.0764 - auc_2: 0.5210 - recall_2: 0.0027 - precision_2: 0.2370 - hamming_loss: 0.9973 - f1_score: 0.0051 - val_loss: 2.8594 - val_acc: 0.0670 - val_auc_2: 0.5105 - val_recall_2: 0.0027 - val_precision_2: 0.1481 - val_hamming_loss: 0.9973 - val_f1_score: 0.0050
# Epoch 6/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7712 - acc: 0.0791 - auc_2: 0.5280 - recall_2: 0.0031 - precision_2: 0.2747 - hamming_loss: 0.9969 - f1_score: 0.0061 - val_loss: 2.7737 - val_acc: 0.0737 - val_auc_2: 0.5268 - val_recall_2: 0.0057 - val_precision_2: 0.4595 - val_hamming_loss: 0.9943 - val_f1_score: 0.0108
# Epoch 7/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7649 - acc: 0.0790 - auc_2: 0.5280 - recall_2: 0.0030 - precision_2: 0.3100 - hamming_loss: 0.9970 - f1_score: 0.0057 - val_loss: 2.8906 - val_acc: 0.0790 - val_auc_2: 0.5228 - val_recall_2: 0.0073 - val_precision_2: 0.1913 - val_hamming_loss: 0.9927 - val_f1_score: 0.0125
# Epoch 8/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7590 - acc: 0.0806 - auc_2: 0.5286 - recall_2: 0.0039 - precision_2: 0.3924 - hamming_loss: 0.9961 - f1_score: 0.0075 - val_loss: 2.7600 - val_acc: 0.0803 - val_auc_2: 0.5274 - val_recall_2: 0.0020 - val_precision_2: 0.3000 - val_hamming_loss: 0.9980 - val_f1_score: 0.0039
# Epoch 9/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7541 - acc: 0.0798 - auc_2: 0.5295 - recall_2: 0.0034 - precision_2: 0.3612 - hamming_loss: 0.9966 - f1_score: 0.0066 - val_loss: 2.7662 - val_acc: 0.0717 - val_auc_2: 0.5154 - val_recall_2: 0.0047 - val_precision_2: 0.5185 - val_hamming_loss: 0.9953 - val_f1_score: 0.0091
# Epoch 10/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7424 - acc: 0.0832 - auc_2: 0.5327 - recall_2: 0.0040 - precision_2: 0.4093 - hamming_loss: 0.9960 - f1_score: 0.0078 - val_loss: 2.7497 - val_acc: 0.0817 - val_auc_2: 0.5326 - val_recall_2: 0.0040 - val_precision_2: 0.4000 - val_hamming_loss: 0.9960 - val_f1_score: 0.0076
# ******************* Model evaluation for a momentum of 0.2 *************************
# 94/94 [==============================] - 10s 85ms/step - loss: 2.7572 - acc: 0.0853 - auc_2: 0.5199 - recall_2: 0.0057 - precision_2: 0.4722 - hamming_loss: 0.9943 - f1_score: 0.0107
# ******************* Train time is 3133.6828799549994 ***********
# f1 score is 0.010727943045397599
# ******************* Training model for momentum of 0.2 ************************
# Epoch 1/10
# 200/200 [==============================] - 164s 787ms/step - loss: 2.8848 - acc: 0.0690 - auc_3: 0.5096 - recall_3: 0.0024 - precision_3: 0.1436 - hamming_loss: 0.9976 - f1_score: 0.0047 - val_loss: 2.8602 - val_acc: 0.0713 - val_auc_3: 0.5142 - val_recall_3: 0.0040 - val_precision_3: 0.1818 - val_hamming_loss: 0.9960 - val_f1_score: 0.0074
# Epoch 2/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.8112 - acc: 0.0742 - auc_3: 0.5152 - recall_3: 0.0024 - precision_3: 0.1759 - hamming_loss: 0.9976 - f1_score: 0.0046 - val_loss: 2.8289 - val_acc: 0.0723 - val_auc_3: 0.5106 - val_recall_3: 0.0027 - val_precision_3: 0.1633 - val_hamming_loss: 0.9973 - val_f1_score: 0.0051
# Epoch 3/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7900 - acc: 0.0738 - auc_3: 0.5195 - recall_3: 0.0028 - precision_3: 0.2393 - hamming_loss: 0.9972 - f1_score: 0.0054 - val_loss: 2.8151 - val_acc: 0.0773 - val_auc_3: 0.5123 - val_recall_3: 0.0033 - val_precision_3: 0.2273 - val_hamming_loss: 0.9967 - val_f1_score: 0.0064
# Epoch 4/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7764 - acc: 0.0797 - auc_3: 0.5232 - recall_3: 0.0032 - precision_3: 0.2601 - hamming_loss: 0.9968 - f1_score: 0.0062 - val_loss: 2.7760 - val_acc: 0.0760 - val_auc_3: 0.5201 - val_recall_3: 0.0040 - val_precision_3: 0.4138 - val_hamming_loss: 0.9960 - val_f1_score: 0.0076
# Epoch 5/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7656 - acc: 0.0770 - auc_3: 0.5249 - recall_3: 0.0034 - precision_3: 0.3228 - hamming_loss: 0.9966 - f1_score: 0.0066 - val_loss: 2.7817 - val_acc: 0.0843 - val_auc_3: 0.5217 - val_recall_3: 0.0043 - val_precision_3: 0.3824 - val_hamming_loss: 0.9957 - val_f1_score: 0.0082
# Epoch 6/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7550 - acc: 0.0772 - auc_3: 0.5264 - recall_3: 0.0034 - precision_3: 0.3460 - hamming_loss: 0.9966 - f1_score: 0.0066 - val_loss: 2.7539 - val_acc: 0.0750 - val_auc_3: 0.5237 - val_recall_3: 0.0030 - val_precision_3: 0.3913 - val_hamming_loss: 0.9970 - val_f1_score: 0.0058
# Epoch 7/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7443 - acc: 0.0815 - auc_3: 0.5297 - recall_3: 0.0040 - precision_3: 0.4199 - hamming_loss: 0.9960 - f1_score: 0.0078 - val_loss: 2.7560 - val_acc: 0.0780 - val_auc_3: 0.5175 - val_recall_3: 0.0060 - val_precision_3: 0.5806 - val_hamming_loss: 0.9940 - val_f1_score: 0.0116
# Epoch 8/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7372 - acc: 0.0827 - auc_3: 0.5311 - recall_3: 0.0040 - precision_3: 0.4292 - hamming_loss: 0.9960 - f1_score: 0.0078 - val_loss: 2.8430 - val_acc: 0.0763 - val_auc_3: 0.5095 - val_recall_3: 0.0060 - val_precision_3: 0.2368 - val_hamming_loss: 0.9940 - val_f1_score: 0.0108
# Epoch 9/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7345 - acc: 0.0820 - auc_3: 0.5330 - recall_3: 0.0040 - precision_3: 0.4409 - hamming_loss: 0.9960 - f1_score: 0.0078 - val_loss: 2.7288 - val_acc: 0.0790 - val_auc_3: 0.5298 - val_recall_3: 0.0053 - val_precision_3: 0.5161 - val_hamming_loss: 0.9947 - val_f1_score: 0.0102
# Epoch 10/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7237 - acc: 0.0867 - auc_3: 0.5369 - recall_3: 0.0041 - precision_3: 0.4804 - hamming_loss: 0.9959 - f1_score: 0.0079 - val_loss: 2.7426 - val_acc: 0.0797 - val_auc_3: 0.5273 - val_recall_3: 0.0053 - val_precision_3: 0.4706 - val_hamming_loss: 0.9947 - val_f1_score: 0.0103
# ******************* Model evaluation for a momentum of 0.30000000000000004 *************************
# 94/94 [==============================] - 10s 85ms/step - loss: 2.7436 - acc: 0.0767 - auc_3: 0.5304 - recall_3: 0.0053 - precision_3: 0.4706 - hamming_loss: 0.9947 - f1_score: 0.0102
# ******************* Train time is 4699.407205115998 ***********
# f1 score is 0.010215074693163236
# ******************* Training model for momentum of 0.30000000000000004 ************************
# Epoch 1/10
# 200/200 [==============================] - 165s 787ms/step - loss: 2.8605 - acc: 0.0694 - auc_4: 0.5077 - recall_4: 0.0025 - precision_4: 0.1369 - hamming_loss: 0.9975 - f1_score: 0.0047 - val_loss: 2.7906 - val_acc: 0.0837 - val_auc_4: 0.5180 - val_recall_4: 0.0037 - val_precision_4: 0.3143 - val_hamming_loss: 0.9963 - val_f1_score: 0.0070
# Epoch 2/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7875 - acc: 0.0750 - auc_4: 0.5167 - recall_4: 0.0032 - precision_4: 0.2436 - hamming_loss: 0.9968 - f1_score: 0.0061 - val_loss: 2.7618 - val_acc: 0.0763 - val_auc_4: 0.5312 - val_recall_4: 0.0053 - val_precision_4: 0.3721 - val_hamming_loss: 0.9947 - val_f1_score: 0.0102
# Epoch 3/10
# 200/200 [==============================] - 156s 778ms/step - loss: 2.7643 - acc: 0.0791 - auc_4: 0.5249 - recall_4: 0.0037 - precision_4: 0.3132 - hamming_loss: 0.9963 - f1_score: 0.0071 - val_loss: 2.7494 - val_acc: 0.0817 - val_auc_4: 0.5329 - val_recall_4: 0.0063 - val_precision_4: 0.4222 - val_hamming_loss: 0.9937 - val_f1_score: 0.0118
# Epoch 4/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7409 - acc: 0.0831 - auc_4: 0.5312 - recall_4: 0.0055 - precision_4: 0.4599 - hamming_loss: 0.9945 - f1_score: 0.0106 - val_loss: 2.7566 - val_acc: 0.0787 - val_auc_4: 0.5248 - val_recall_4: 0.0043 - val_precision_4: 0.3824 - val_hamming_loss: 0.9957 - val_f1_score: 0.0083
# Epoch 5/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7276 - acc: 0.0843 - auc_4: 0.5388 - recall_4: 0.0052 - precision_4: 0.4737 - hamming_loss: 0.9948 - f1_score: 0.0101 - val_loss: 2.7478 - val_acc: 0.0717 - val_auc_4: 0.5286 - val_recall_4: 0.0057 - val_precision_4: 0.4595 - val_hamming_loss: 0.9943 - val_f1_score: 0.0110
# Epoch 6/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7222 - acc: 0.0866 - auc_4: 0.5369 - recall_4: 0.0063 - precision_4: 0.5451 - hamming_loss: 0.9937 - f1_score: 0.0122 - val_loss: 2.7433 - val_acc: 0.0873 - val_auc_4: 0.5248 - val_recall_4: 0.0067 - val_precision_4: 0.5128 - val_hamming_loss: 0.9933 - val_f1_score: 0.0126
# Epoch 7/10
# 200/200 [==============================] - 161s 806ms/step - loss: 2.7116 - acc: 0.0869 - auc_4: 0.5430 - recall_4: 0.0064 - precision_4: 0.5560 - hamming_loss: 0.9936 - f1_score: 0.0125 - val_loss: 2.7216 - val_acc: 0.0890 - val_auc_4: 0.5422 - val_recall_4: 0.0063 - val_precision_4: 0.5000 - val_hamming_loss: 0.9937 - val_f1_score: 0.0120
# Epoch 8/10
# 200/200 [==============================] - 161s 805ms/step - loss: 2.6984 - acc: 0.0901 - auc_4: 0.5486 - recall_4: 0.0070 - precision_4: 0.5350 - hamming_loss: 0.9930 - f1_score: 0.0135 - val_loss: 2.7072 - val_acc: 0.0917 - val_auc_4: 0.5462 - val_recall_4: 0.0063 - val_precision_4: 0.4634 - val_hamming_loss: 0.9937 - val_f1_score: 0.0122
# Epoch 9/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.6928 - acc: 0.0911 - auc_4: 0.5513 - recall_4: 0.0083 - precision_4: 0.6515 - hamming_loss: 0.9917 - f1_score: 0.0161 - val_loss: 2.6992 - val_acc: 0.0770 - val_auc_4: 0.5450 - val_recall_4: 0.0077 - val_precision_4: 0.6389 - val_hamming_loss: 0.9923 - val_f1_score: 0.0148
# Epoch 10/10
# 200/200 [==============================] - 156s 781ms/step - loss: 2.6868 - acc: 0.0934 - auc_4: 0.5538 - recall_4: 0.0093 - precision_4: 0.6483 - hamming_loss: 0.9907 - f1_score: 0.0179 - val_loss: 2.7129 - val_acc: 0.0923 - val_auc_4: 0.5376 - val_recall_4: 0.0080 - val_precision_4: 0.5455 - val_hamming_loss: 0.9920 - val_f1_score: 0.0152
# ******************* Model evaluation for a momentum of 0.4 *************************
# 94/94 [==============================] - 10s 89ms/step - loss: 2.7025 - acc: 0.0890 - auc_4: 0.5483 - recall_4: 0.0083 - precision_4: 0.5556 - hamming_loss: 0.9917 - f1_score: 0.0160
# ******************* Train time is 6277.079562067999 ***********
# f1 score is 0.016040737678607305
# ******************* Training model for momentum of 0.4 ************************
# Epoch 1/10
# 200/200 [==============================] - 165s 788ms/step - loss: 2.8338 - acc: 0.0701 - auc_5: 0.5127 - recall_5: 0.0036 - precision_5: 0.1928 - hamming_loss: 0.9964 - f1_score: 0.0069 - val_loss: 2.7878 - val_acc: 0.0800 - val_auc_5: 0.5295 - val_recall_5: 0.0057 - val_precision_5: 0.2698 - val_hamming_loss: 0.9943 - val_f1_score: 0.0108
# Epoch 2/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7604 - acc: 0.0814 - auc_5: 0.5294 - recall_5: 0.0052 - precision_5: 0.3125 - hamming_loss: 0.9948 - f1_score: 0.0100 - val_loss: 2.7479 - val_acc: 0.0857 - val_auc_5: 0.5325 - val_recall_5: 0.0070 - val_precision_5: 0.4884 - val_hamming_loss: 0.9930 - val_f1_score: 0.0132
# Epoch 3/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7304 - acc: 0.0863 - auc_5: 0.5371 - recall_5: 0.0069 - precision_5: 0.4499 - hamming_loss: 0.9931 - f1_score: 0.0133 - val_loss: 2.7189 - val_acc: 0.0960 - val_auc_5: 0.5481 - val_recall_5: 0.0113 - val_precision_5: 0.5484 - val_hamming_loss: 0.9887 - val_f1_score: 0.0211
# Epoch 4/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7209 - acc: 0.0876 - auc_5: 0.5431 - recall_5: 0.0073 - precision_5: 0.4548 - hamming_loss: 0.9927 - f1_score: 0.0141 - val_loss: 2.7309 - val_acc: 0.0930 - val_auc_5: 0.5400 - val_recall_5: 0.0077 - val_precision_5: 0.4694 - val_hamming_loss: 0.9923 - val_f1_score: 0.0147
# Epoch 5/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.7141 - acc: 0.0885 - auc_5: 0.5421 - recall_5: 0.0091 - precision_5: 0.5253 - hamming_loss: 0.9909 - f1_score: 0.0175 - val_loss: 2.7085 - val_acc: 0.0850 - val_auc_5: 0.5459 - val_recall_5: 0.0077 - val_precision_5: 0.5227 - val_hamming_loss: 0.9923 - val_f1_score: 0.0148
# Epoch 6/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.6934 - acc: 0.0947 - auc_5: 0.5513 - recall_5: 0.0099 - precision_5: 0.6103 - hamming_loss: 0.9901 - f1_score: 0.0192 - val_loss: 2.7019 - val_acc: 0.0907 - val_auc_5: 0.5440 - val_recall_5: 0.0113 - val_precision_5: 0.6071 - val_hamming_loss: 0.9887 - val_f1_score: 0.0216
# Epoch 7/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6759 - acc: 0.1015 - auc_5: 0.5598 - recall_5: 0.0128 - precision_5: 0.6784 - hamming_loss: 0.9872 - f1_score: 0.0248 - val_loss: 2.6815 - val_acc: 0.0990 - val_auc_5: 0.5624 - val_recall_5: 0.0120 - val_precision_5: 0.5902 - val_hamming_loss: 0.9880 - val_f1_score: 0.0229
# Epoch 8/10
# 200/200 [==============================] - 156s 778ms/step - loss: 2.6669 - acc: 0.1040 - auc_5: 0.5646 - recall_5: 0.0137 - precision_5: 0.7269 - hamming_loss: 0.9862 - f1_score: 0.0265 - val_loss: 2.6701 - val_acc: 0.0937 - val_auc_5: 0.5634 - val_recall_5: 0.0110 - val_precision_5: 0.6735 - val_hamming_loss: 0.9890 - val_f1_score: 0.0212
# Epoch 9/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6622 - acc: 0.1046 - auc_5: 0.5686 - recall_5: 0.0132 - precision_5: 0.6943 - hamming_loss: 0.9868 - f1_score: 0.0255 - val_loss: 2.6677 - val_acc: 0.0947 - val_auc_5: 0.5630 - val_recall_5: 0.0130 - val_precision_5: 0.7222 - val_hamming_loss: 0.9870 - val_f1_score: 0.0251
# Epoch 10/10
# 200/200 [==============================] - 156s 778ms/step - loss: 2.6504 - acc: 0.1060 - auc_5: 0.5754 - recall_5: 0.0151 - precision_5: 0.7202 - hamming_loss: 0.9849 - f1_score: 0.0291 - val_loss: 2.6625 - val_acc: 0.1000 - val_auc_5: 0.5668 - val_recall_5: 0.0130 - val_precision_5: 0.6610 - val_hamming_loss: 0.9870 - val_f1_score: 0.0248
# ******************* Model evaluation for a momentum of 0.5 *************************
# 94/94 [==============================] - 10s 89ms/step - loss: 2.6781 - acc: 0.0947 - auc_5: 0.5614 - recall_5: 0.0110 - precision_5: 0.6000 - hamming_loss: 0.9890 - f1_score: 0.0211
# ******************* Train time is 7843.961425981 ***********
# f1 score is 0.021102286813159784
# ******************* Training model for momentum of 0.5 ************************
# Epoch 1/10
# 200/200 [==============================] - 165s 788ms/step - loss: 2.8310 - acc: 0.0711 - auc_6: 0.5110 - recall_6: 0.0048 - precision_6: 0.2156 - hamming_loss: 0.9952 - f1_score: 0.0092 - val_loss: 2.7781 - val_acc: 0.0743 - val_auc_6: 0.5118 - val_recall_6: 0.0067 - val_precision_6: 0.3279 - val_hamming_loss: 0.9933 - val_f1_score: 0.0125
# Epoch 2/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.7335 - acc: 0.0840 - auc_6: 0.5341 - recall_6: 0.0086 - precision_6: 0.4662 - hamming_loss: 0.9914 - f1_score: 0.0166 - val_loss: 2.7256 - val_acc: 0.0890 - val_auc_6: 0.5387 - val_recall_6: 0.0107 - val_precision_6: 0.5517 - val_hamming_loss: 0.9893 - val_f1_score: 0.0204
# Epoch 3/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.6978 - acc: 0.0950 - auc_6: 0.5489 - recall_6: 0.0120 - precision_6: 0.5723 - hamming_loss: 0.9880 - f1_score: 0.0231 - val_loss: 2.7167 - val_acc: 0.0840 - val_auc_6: 0.5431 - val_recall_6: 0.0100 - val_precision_6: 0.4615 - val_hamming_loss: 0.9900 - val_f1_score: 0.0191
# Epoch 4/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.6749 - acc: 0.1006 - auc_6: 0.5609 - recall_6: 0.0145 - precision_6: 0.6660 - hamming_loss: 0.9855 - f1_score: 0.0279 - val_loss: 2.6859 - val_acc: 0.0990 - val_auc_6: 0.5531 - val_recall_6: 0.0120 - val_precision_6: 0.7347 - val_hamming_loss: 0.9880 - val_f1_score: 0.0230
# Epoch 5/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6522 - acc: 0.1064 - auc_6: 0.5700 - recall_6: 0.0172 - precision_6: 0.7133 - hamming_loss: 0.9828 - f1_score: 0.0331 - val_loss: 2.6884 - val_acc: 0.0960 - val_auc_6: 0.5516 - val_recall_6: 0.0153 - val_precision_6: 0.5897 - val_hamming_loss: 0.9847 - val_f1_score: 0.0292
# Epoch 6/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6381 - acc: 0.1116 - auc_6: 0.5777 - recall_6: 0.0202 - precision_6: 0.7748 - hamming_loss: 0.9798 - f1_score: 0.0389 - val_loss: 2.6708 - val_acc: 0.1050 - val_auc_6: 0.5600 - val_recall_6: 0.0193 - val_precision_6: 0.7250 - val_hamming_loss: 0.9807 - val_f1_score: 0.0368
# Epoch 7/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.6247 - acc: 0.1157 - auc_6: 0.5831 - recall_6: 0.0223 - precision_6: 0.8021 - hamming_loss: 0.9777 - f1_score: 0.0428 - val_loss: 2.6596 - val_acc: 0.1113 - val_auc_6: 0.5665 - val_recall_6: 0.0173 - val_precision_6: 0.7123 - val_hamming_loss: 0.9827 - val_f1_score: 0.0331
# Epoch 8/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6140 - acc: 0.1214 - auc_6: 0.5927 - recall_6: 0.0235 - precision_6: 0.7952 - hamming_loss: 0.9765 - f1_score: 0.0450 - val_loss: 2.6532 - val_acc: 0.1033 - val_auc_6: 0.5691 - val_recall_6: 0.0187 - val_precision_6: 0.7179 - val_hamming_loss: 0.9813 - val_f1_score: 0.0358
# Epoch 9/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.5988 - acc: 0.1267 - auc_6: 0.6017 - recall_6: 0.0253 - precision_6: 0.8139 - hamming_loss: 0.9747 - f1_score: 0.0485 - val_loss: 2.6455 - val_acc: 0.1147 - val_auc_6: 0.5813 - val_recall_6: 0.0203 - val_precision_6: 0.6703 - val_hamming_loss: 0.9797 - val_f1_score: 0.0386
# Epoch 10/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.5834 - acc: 0.1342 - auc_6: 0.6111 - recall_6: 0.0276 - precision_6: 0.8511 - hamming_loss: 0.9724 - f1_score: 0.0529 - val_loss: 2.6151 - val_acc: 0.1257 - val_auc_6: 0.5997 - val_recall_6: 0.0227 - val_precision_6: 0.7556 - val_hamming_loss: 0.9773 - val_f1_score: 0.0433
# ******************* Model evaluation for a momentum of 0.6 *************************
# 94/94 [==============================] - 10s 88ms/step - loss: 2.6280 - acc: 0.1283 - auc_6: 0.5891 - recall_6: 0.0223 - precision_6: 0.7053 - hamming_loss: 0.9777 - f1_score: 0.0426
# ******************* Train time is 9411.863882071999 ***********
# f1 score is 0.04257908978809913
# ******************* Training model for momentum of 0.6 ************************
# Epoch 1/10
# 200/200 [==============================] - 164s 788ms/step - loss: 2.7646 - acc: 0.0805 - auc_7: 0.5231 - recall_7: 0.0060 - precision_7: 0.3199 - hamming_loss: 0.9940 - f1_score: 0.0114 - val_loss: 2.7387 - val_acc: 0.0883 - val_auc_7: 0.5303 - val_recall_7: 0.0120 - val_precision_7: 0.4675 - val_hamming_loss: 0.9880 - val_f1_score: 0.0225
# Epoch 2/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6822 - acc: 0.0961 - auc_7: 0.5537 - recall_7: 0.0131 - precision_7: 0.6501 - hamming_loss: 0.9869 - f1_score: 0.0251 - val_loss: 2.7111 - val_acc: 0.0863 - val_auc_7: 0.5420 - val_recall_7: 0.0100 - val_precision_7: 0.5172 - val_hamming_loss: 0.9900 - val_f1_score: 0.0189
# Epoch 3/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6576 - acc: 0.1033 - auc_7: 0.5660 - recall_7: 0.0176 - precision_7: 0.7339 - hamming_loss: 0.9824 - f1_score: 0.0337 - val_loss: 2.6775 - val_acc: 0.1067 - val_auc_7: 0.5537 - val_recall_7: 0.0173 - val_precision_7: 0.7222 - val_hamming_loss: 0.9827 - val_f1_score: 0.0330
# Epoch 4/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6299 - acc: 0.1151 - auc_7: 0.5802 - recall_7: 0.0211 - precision_7: 0.8057 - hamming_loss: 0.9789 - f1_score: 0.0405 - val_loss: 2.6538 - val_acc: 0.1200 - val_auc_7: 0.5682 - val_recall_7: 0.0207 - val_precision_7: 0.6966 - val_hamming_loss: 0.9793 - val_f1_score: 0.0392
# Epoch 5/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6097 - acc: 0.1213 - auc_7: 0.5939 - recall_7: 0.0240 - precision_7: 0.7986 - hamming_loss: 0.9760 - f1_score: 0.0459 - val_loss: 2.6427 - val_acc: 0.1143 - val_auc_7: 0.5767 - val_recall_7: 0.0203 - val_precision_7: 0.6854 - val_hamming_loss: 0.9797 - val_f1_score: 0.0385
# Epoch 6/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.5894 - acc: 0.1331 - auc_7: 0.6056 - recall_7: 0.0270 - precision_7: 0.8416 - hamming_loss: 0.9730 - f1_score: 0.0516 - val_loss: 2.6294 - val_acc: 0.1173 - val_auc_7: 0.5902 - val_recall_7: 0.0247 - val_precision_7: 0.7184 - val_hamming_loss: 0.9753 - val_f1_score: 0.0466
# Epoch 7/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.5748 - acc: 0.1367 - auc_7: 0.6160 - recall_7: 0.0294 - precision_7: 0.8547 - hamming_loss: 0.9706 - f1_score: 0.0561 - val_loss: 2.6243 - val_acc: 0.1247 - val_auc_7: 0.5889 - val_recall_7: 0.0227 - val_precision_7: 0.7727 - val_hamming_loss: 0.9773 - val_f1_score: 0.0433
# Epoch 8/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.5579 - acc: 0.1466 - auc_7: 0.6257 - recall_7: 0.0323 - precision_7: 0.8858 - hamming_loss: 0.9677 - f1_score: 0.0617 - val_loss: 2.6096 - val_acc: 0.1343 - val_auc_7: 0.5986 - val_recall_7: 0.0220 - val_precision_7: 0.7952 - val_hamming_loss: 0.9780 - val_f1_score: 0.0422
# Epoch 9/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.5506 - acc: 0.1471 - auc_7: 0.6289 - recall_7: 0.0352 - precision_7: 0.8810 - hamming_loss: 0.9648 - f1_score: 0.0669 - val_loss: 2.5974 - val_acc: 0.1370 - val_auc_7: 0.6165 - val_recall_7: 0.0263 - val_precision_7: 0.8316 - val_hamming_loss: 0.9737 - val_f1_score: 0.0503
# Epoch 10/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.5250 - acc: 0.1621 - auc_7: 0.6472 - recall_7: 0.0382 - precision_7: 0.9180 - hamming_loss: 0.9617 - f1_score: 0.0728 - val_loss: 2.5988 - val_acc: 0.1303 - val_auc_7: 0.6097 - val_recall_7: 0.0310 - val_precision_7: 0.7323 - val_hamming_loss: 0.9690 - val_f1_score: 0.0586
# ******************* Model evaluation for a momentum of 0.7 *************************
# 94/94 [==============================] - 10s 90ms/step - loss: 2.5823 - acc: 0.1330 - auc_7: 0.6141 - recall_7: 0.0330 - precision_7: 0.7557 - hamming_loss: 0.9670 - f1_score: 0.0623
# ******************* Train time is 10978.421609042998 ***********
# f1 score is 0.062341793316106
# ******************* Training model for momentum of 0.7 ************************
# Epoch 1/10
# 200/200 [==============================] - 164s 788ms/step - loss: 2.7411 - acc: 0.0841 - auc_8: 0.5329 - recall_8: 0.0087 - precision_8: 0.4122 - hamming_loss: 0.9913 - f1_score: 0.0167 - val_loss: 2.6814 - val_acc: 0.0933 - val_auc_8: 0.5528 - val_recall_8: 0.0157 - val_precision_8: 0.6104 - val_hamming_loss: 0.9843 - val_f1_score: 0.0296
# Epoch 2/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.6433 - acc: 0.1107 - auc_8: 0.5752 - recall_8: 0.0185 - precision_8: 0.7014 - hamming_loss: 0.9815 - f1_score: 0.0355 - val_loss: 2.6611 - val_acc: 0.1063 - val_auc_8: 0.5600 - val_recall_8: 0.0207 - val_precision_8: 0.5741 - val_hamming_loss: 0.9793 - val_f1_score: 0.0389
# Epoch 3/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.6014 - acc: 0.1276 - auc_8: 0.6019 - recall_8: 0.0256 - precision_8: 0.7956 - hamming_loss: 0.9744 - f1_score: 0.0490 - val_loss: 2.6383 - val_acc: 0.1187 - val_auc_8: 0.5828 - val_recall_8: 0.0223 - val_precision_8: 0.7882 - val_hamming_loss: 0.9777 - val_f1_score: 0.0429
# Epoch 4/10
# 200/200 [==============================] - 156s 780ms/step - loss: 2.5731 - acc: 0.1422 - auc_8: 0.6166 - recall_8: 0.0307 - precision_8: 0.8491 - hamming_loss: 0.9693 - f1_score: 0.0586 - val_loss: 2.6248 - val_acc: 0.1260 - val_auc_8: 0.6012 - val_recall_8: 0.0250 - val_precision_8: 0.6637 - val_hamming_loss: 0.9750 - val_f1_score: 0.0476
# Epoch 5/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.5425 - acc: 0.1580 - auc_8: 0.6361 - recall_8: 0.0363 - precision_8: 0.8933 - hamming_loss: 0.9637 - f1_score: 0.0691 - val_loss: 2.6102 - val_acc: 0.1320 - val_auc_8: 0.6018 - val_recall_8: 0.0277 - val_precision_8: 0.7281 - val_hamming_loss: 0.9723 - val_f1_score: 0.0526
# Epoch 6/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.5176 - acc: 0.1697 - auc_8: 0.6544 - recall_8: 0.0381 - precision_8: 0.8901 - hamming_loss: 0.9619 - f1_score: 0.0725 - val_loss: 2.5779 - val_acc: 0.1560 - val_auc_8: 0.6322 - val_recall_8: 0.0253 - val_precision_8: 0.7308 - val_hamming_loss: 0.9747 - val_f1_score: 0.0482
# Epoch 7/10
# 200/200 [==============================] - 156s 779ms/step - loss: 2.4936 - acc: 0.1798 - auc_8: 0.6671 - recall_8: 0.0420 - precision_8: 0.9156 - hamming_loss: 0.9580 - f1_score: 0.0797 - val_loss: 2.5737 - val_acc: 0.1483 - val_auc_8: 0.6345 - val_recall_8: 0.0297 - val_precision_8: 0.6742 - val_hamming_loss: 0.9703 - val_f1_score: 0.0560
# Epoch 8/10
#  67/200 [=========>....................] - ETA: 1:40 - loss: 2.4634 - acc: 0.1981 - auc_8: 0.6837 - recall_8: 0.0466 - precision_8: 0.9422 - hamming_loss: 0.9534 - f1_score: 0.0885
